# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

def reading(a):
    data=pd.read_csv(a,usecols=['YearsExperience','Salary'])
    return data
    
data=reading('Salary_dataset.csv')
print(data.loc[:4])
plt.scatter(data['YearsExperience'],data['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('YearsExperience vs Salary')
plt.show()
#The plot seems to be linear

x=data[['YearsExperience']]
y=data['Salary']
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

model=LinearRegression()
model.fit(xtrain,ytrain)
prediction=model.predict(xtest)

m=mean_squared_error(ytest,prediction)
print("Mean square error: ",m)

r2=r2_score(ytest,prediction)
print("R2 score: ",r2)

if r2==1:
    print("perfectly fit model")
elif r2>0.75:
    print("Most of variance is explained well")
elif r2>0.5:
    print("The model is moderately accurate")
else:
    print("The model has poor prediction power")
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0
# Mean square error:  49830096.855908334
# R2 score:  0.9024461774180498
# Most of variance is explained well
